# %% [markdown]
# <a href="https://colab.research.google.com/github/audricms/Introduction-and-Experimentation-with-GAN/blob/main/Zak_projet_gan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/audricms/Introduction-and-Experimentation-with-GAN.git
# Out:
# Cloning into 'Introduction-and-Experimentation-with-GAN'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 11 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 25.54 KiB | 6.38 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd Introduction-and-Experimentation-with-GAN
# !ls
# Out:
# /content/Introduction-and-Experimentation-with-GAN
# LICENSE  Practical_3b_Deep_Generative_Models.ipynb  README.md
